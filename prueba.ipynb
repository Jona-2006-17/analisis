# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://intern:internpass@localhost:5433/intern_db"
)

# %%
df_sessions = pd.read_sql("SELECT * FROM sessions;", engine)
lista = []

#df_sessions = df_sessions[~df_sessions['user_id'].isin(lista)]
df_sessions['start_time'] = pd.to_datetime(df_sessions['start_time'])
df_sessions['end_time'] = pd.to_datetime(df_sessions['end_time'])


df_sessions['duracion_session_min'] = ((df_sessions['end_time']-df_sessions['start_time']).dt.total_seconds() / 60).round(2)
df_sessions['duracion_session_horas'] = df_sessions['duracion_session_min'] / 60

df_session_mayor_8_horas = df_sessions[df_sessions['duracion_session_horas'] > 8]

lista.extend(df_session_mayor_8_horas['id'].to_list())

#df_session_mayor_8_horas
lista 
df_sessions = df_sessions[~df_sessions['id'].isin(lista)]

promedio = df_sessions['duracion_session_horas'].mean()
df_session_mayor_8_horas
# df_sessions.head(20)
# 25
# 641
# 3
# 7
# 26
# 2791
# promedio = df_sessios['duracion_session_horas'].mean()
# promedio.round(2)
# Out:
#         id  user_id                       start_time  \
# 1       25        2 2025-10-22 21:01:15.447877+00:00
# 2      641      326 2025-11-13 13:31:29.896718+00:00
# 11       3        2 2025-09-30 15:28:20.048213+00:00
# 15       7        1 2025-10-02 16:44:32.110896+00:00
# 17      26        1 2025-10-23 00:09:51.667976+00:00
# ...    ...      ...                              ...
# 6538  6595     3939 2026-01-14 20:52:35.076995+00:00
# 6571  6574     3924 2026-01-14 19:00:26.287124+00:00
# 6572  6439     3848 2026-01-13 19:22:43.188617+00:00
# 6595  6508     3887 2026-01-14 14:20:36.826045+00:00
# 6596  6622     3911 2026-01-14 23:46:16.933724+00:00
#
#                              end_time  status  conv_id  bot_feedback  \
# 1    2025-10-23 13:50:48.339044+00:00  closed    198.0           NaN
# 2    2025-11-14 13:21:32.275703+00:00  closed      NaN           NaN
# 11   2025-10-01 15:02:42.910438+00:00  closed    175.0           NaN
# ...

# %%
df = pd.read_sql("SELECT * FROM conversation_context WHERE user_input IS NOT NULL OR system_input IS NOT NULL", engine)
df.head(25)
# Out:
#       id  session_id      state  \
# 0   3215          41      debut
# 1   3217          41  main_menu
# 2   3218          41  main_menu
# 3   3220          41   handover
# 4   3221          41   handover
# 5   3222          41   handover
# 6   3223          41   handover
# 7   3224          41   handover
# 8   3225          41   handover
# 9    306           3      debut
# 10   308           3  main_menu
# 11   309           3  main_menu
# 12   102           1      debut
# 13   104           1  main_menu
# 14   105           1  main_menu
# 15   107           1   handover
# 16   108           1   handover
# 17   109           1   handover
# 18   110           1   handover
# 19   111           1   handover
# 20   112           1   handover
# 21   113           1   handover
# 22   115           1   feedback
# 23   116           1   feedback
# 24   118           1      final
#
#                                            user_input  \
# ...

# %%
df2 = pd.read_sql("SELECT * FROM essential_context ;", engine)
df2.head()
# Out:
#    id  session_id                                          situation  \
# 0   1           1  el sistema le presento al usuario el menu prin...
# 1   2           3  el sistema le presento al usuario el menu prin...
# 2   3           2  el sistema le presento al usuario el menu prin...
# 3   4           4  el sistema le presento al usuario el menu prin...
# 4   5           5  el sistema le presento al usuario el menu prin...
#
#                                          user_intent user_data  \
# 0  intencion commercial: el usuario desea agendar...      None
# 1  intencion commercial: el usuario desea agendar...      None
# 2  intencion commercial: no hay intencion clara, ...      None
# 3  intencion commercial: el usuario desea saber s...      None
# 4  intencion commercial: no hay intencion clara, ...      None
#
#                          timestamp
# 0 2025-09-30 15:13:35.515969+00:00
# 1 2025-09-30 15:28:29.535441+00:00
# 2 2025-09-30 15:28:35.245198+00:00
# ...

# %%
df3 = pd.read_sql("SELECT * FROM messages", engine)
df3.head(25)
# Out:
#     id  session_id    sender message_type  \
# 0    1           1  customer         text
# 1    2           1  customer         text
# 2    3           1  customer         text
# 3    4           1  customer         text
# 4    5           1  customer         text
# 5    6           1  customer         text
# 6    7           1  customer         text
# 7    8           2  customer         text
# 8    9           3  customer         text
# 9   10           3  customer         text
# 10  11           2  customer         text
# 11  12           3  customer         text
# 12  13           3  customer         text
# 13  14           2  customer         text
# 14  15           4  customer         text
# 15  16           4  customer         text
# 16  17           4  customer         text
# 17  18           4  customer         text
# 18  19           4  customer         text
# 19  20           5  customer         text
# 20  21           5  customer         text
# ...

# %%
prueba = df3['timestamp']
prueba
# Out:
# 0       2025-09-30 15:13:27.147721+00:00
# 1       2025-09-30 15:13:35.511078+00:00
# 2       2025-09-30 15:15:07.343956+00:00
# 3       2025-09-30 15:16:00.069715+00:00
# 4       2025-09-30 15:16:44.399017+00:00
#                       ...
# 45094   2026-01-15 13:47:26.438685+00:00
# 45095   2026-01-15 13:47:32.075548+00:00
# 45096   2026-01-15 13:48:07.082819+00:00
# 45097   2026-01-15 13:48:08.590953+00:00
# 45098   2026-01-15 13:48:08.676886+00:00
# Name: timestamp, Length: 45099, dtype: datetime64[ns, UTC]
